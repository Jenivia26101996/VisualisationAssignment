# %%
import pandas as pd
import matplotlib.pyplot as plt
 
data=pd.read_excel("C:/Users/Huawei/Desktop/VisualisationAssignment/suicideratedata.xlsx") #Reading data from excel file  
print(data)
data_drop=data.drop(["Location","Both sexes"], axis=1) #dropping columns not required for line plot
print(data_drop)
new_data=data_drop.head()                              #selecting the first 5 rows
print(new_data)
period= new_data["Period"].astype(str)
# Out:
#                                              Location  Period  Both sexes  \
# 0   United Kingdom of Great Britain and Northern I...    2019        6.88
# 1   United Kingdom of Great Britain and Northern I...    2018        7.08
# 2   United Kingdom of Great Britain and Northern I...    2017        7.24
# 3   United Kingdom of Great Britain and Northern I...    2016        7.62
# 4   United Kingdom of Great Britain and Northern I...    2015        7.81
# 5   United Kingdom of Great Britain and Northern I...    2014        7.64
# 6   United Kingdom of Great Britain and Northern I...    2013        7.71
# 7   United Kingdom of Great Britain and Northern I...    2012        7.36
# 8   United Kingdom of Great Britain and Northern I...    2011        7.42
# 9   United Kingdom of Great Britain and Northern I...    2010        6.95
# 10  United Kingdom of Great Britain and Northern I...    2009        7.15
# 11  United Kingdom of Great Britain and Northern I...    2008        7.26
# 12  United Kingdom of Great Britain and Northern I...    2007        6.71
# 13  United Kingdom of Great Britain and Northern I...    2006        6.89
# 14  United Kingdom of Great Britain and Northern I...    2005        6.94
# 15  United Kingdom of Great Britain and Northern I...    2004        7.23
# 16  United Kingdom of Great Britain and Northern I...    2003        7.03
# 17  United Kingdom of Great Britain and Northern I...    2002        7.48
# 18  United Kingdom of Great Britain and Northern I...    2001        7.50
# 19  United Kingdom of Great Britain and Northern I...    2000        7.74
#
#      Male  Female
# 0   10.40    3.41
# 1   10.78    3.44
# 2   11.10    3.45
# 3   11.78    3.53
# 4   12.01    3.68
# 5   11.91    3.47
# 6   12.38    3.15
# 7   11.75    3.06
# 8   11.57    3.35
# 9   10.81    3.18
# 10  11.30    3.10
# 11  11.41    3.22
# 12  10.60    2.92
# 13  10.78    3.10
# 14  10.62    3.39
# 15  11.09    3.48
# 16  10.90    3.28
# 17  11.69    3.38
# 18  11.95    3.22
# 19  12.02    3.62
#     Period   Male  Female
# 0     2019  10.40    3.41
# 1     2018  10.78    3.44
# 2     2017  11.10    3.45
# 3     2016  11.78    3.53
# 4     2015  12.01    3.68
# 5     2014  11.91    3.47
# 6     2013  12.38    3.15
# 7     2012  11.75    3.06
# 8     2011  11.57    3.35
# 9     2010  10.81    3.18
# 10    2009  11.30    3.10
# 11    2008  11.41    3.22
# 12    2007  10.60    2.92
# 13    2006  10.78    3.10
# 14    2005  10.62    3.39
# 15    2004  11.09    3.48
# 16    2003  10.90    3.28
# 17    2002  11.69    3.38
# 18    2001  11.95    3.22
# 19    2000  12.02    3.62
#    Period   Male  Female
# 0    2019  10.40    3.41
# 1    2018  10.78    3.44
# 2    2017  11.10    3.45
# 3    2016  11.78    3.53
# 4    2015  12.01    3.68

# %%
def line_plot(x_axis, y_axis, name, colors):           #defining function for line plot with arguments
    plt.plot(x_axis,y_axis,label=name,color=colors) 
plt.figure(dpi=144) #resolution and clarity purpose of graph
line_plot(period, new_data["Male"],"Male","yellow")
line_plot(period, new_data["Female"],"Female","blue")
plt.title("Age-specific Suicide rates")
plt.xlabel("Years")
plt.ylabel("Category")
plt.legend(loc="best") #at the best location it will display the legend
plt.show()

# %%
#dropping Columns location,Male,Female which is not required for pie chart
col_drop=data.drop(["Location","Male","Female"], axis=1)  
print(col_drop)
new_values=col_drop.head()      
print(new_data)
data_both=new_values["Both sexes"]
period=new_values["Period"]

def pie_plot(label,values):                            #defining function for pie plot with arguments
    plt.figure(dpi=144)
    colors = ['yellowgreen', 'red', 'violet', 'lightskyblue', 
          'cyan']
    plt.pie(values, labels=label,colors=colors, startangle=90,radius=1.2,autopct="%1.1f%%",pctdistance=0.5,labeldistance=1.1)
    plt.title("Suicide Rate of Both Sexes(2015-2019)")
    plt.axis("equal")
    plt.tight_layout()
    plt.savefig("Pie_Chart.png")
    plt.show() 
pie_plot(period,data_both)
# Out:
#     Period  Both sexes
# 0     2019        6.88
# 1     2018        7.08
# 2     2017        7.24
# 3     2016        7.62
# 4     2015        7.81
# 5     2014        7.64
# 6     2013        7.71
# 7     2012        7.36
# 8     2011        7.42
# 9     2010        6.95
# 10    2009        7.15
# 11    2008        7.26
# 12    2007        6.71
# 13    2006        6.89
# 14    2005        6.94
# 15    2004        7.23
# 16    2003        7.03
# 17    2002        7.48
# 18    2001        7.50
# 19    2000        7.74
#    Period   Male  Female
# 0    2019  10.40    3.41
# 1    2018  10.78    3.44
# 2    2017  11.10    3.45
# 3    2016  11.78    3.53
# 4    2015  12.01    3.68

# %%
def bar_plot(genre_data):                              #defining function for bar plot with arguments
    #Reading data from csv file for bar plot
    plt.figure(dpi=144)
    colors = ['yellowgreen', 'red', 'lightskyblue', 
              'cyan','lightcoral','blue','pink', 'darkgreen', 
              'yellow','grey','violet','magenta']
    #bar_plot(genre_data["genre"],genre_data["sales"])
    plt.xticks(rotation=90)
    plt.xlabel("Genre")
    plt.ylabel("Sales")
    plt.bar(genre_data["genre"],genre_data["sales"],color=colors)
    plt.title("Total Video Games from 1980-2000")
    plt.savefig("Bar_Plot.png")
    plt.show()
genre_data=pd.read_csv("C:/Users/Huawei/Desktop/VisualisationAssignment/genre_totals.csv")
bar_plot(genre_data)
